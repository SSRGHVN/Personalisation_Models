# %%
import pickle
import pandas as pd
import numpy as np
from scipy.stats import kurtosis
from scipy.stats import skew
import scipy as sc

# %%
train_1=pd.read_csv("C:\\Users\\shreyas.raghavan\\Documents\\Personalization\\train_p.csv")
test1=pd.read_csv("C:\\Users\\shreyas.raghavan\\Documents\\Personalization\\test_p.csv")

# %%
train=train_1.copy()
test=test1.copy()

# %%
del(train['Churn'])
del(train['customerID'])

# %%
del(test['customerID'])

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
for column_name in train.columns:
        if train[column_name].dtype == object:
            train[column_name] = le.fit_transform(train[column_name])
        else:
            pass
features=list(train.columns)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
for column_name in test.columns:
        if test[column_name].dtype == object:
            test[column_name] = le.fit_transform(test[column_name])
        else:
            pass
features=list(test.columns)

# %%
X_train= pd.DataFrame(train)
y_train= pd.DataFrame(train, columns = ["Churn"])
X_test1=pd.DataFrame(test1)
X_test=pd.DataFrame(test)

# %%
y_train1=train_1['Churn'].replace({'No':0,'Yes':1})

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import matplotlib.pyplot as plt
# Gini-model
clf_gini = tree.DecisionTreeClassifier(max_depth=6)
clf_gini.fit(X_train, y_train1)
clf_infoG = tree.DecisionTreeClassifier(criterion="entropy", max_depth=6)
clf_infoG = clf_infoG.fit(X_train, y_train1)
feature_names = list(X_test.columns)
gini_tree = tree.export_graphviz(clf_gini, out_file=None,
                                feature_names=feature_names,
                                class_names='01',
                                filled=True, rounded=True,  
                                special_characters=True)
gini_tree

plt.plot(gini_tree) 

from sklearn.datasets import make_hastie_10_2
from sklearn.ensemble import GradientBoostingClassifier
#X, y = make_hastie_10_2(random_state=0)
#X_train, X_test = X[:2000], X[2000:]
#y_train, y_test = y[:2000], y[2000:]


clf= GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,max_depth=1, random_state=0).fit(X_train, y_train1)
from sklearn.ensemble import AdaBoostClassifier
bdt = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1),
                         algorithm="SAMME",
                         n_estimators=200)

bdt.fit(X_train, y_train1)
# Out:
# AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=200, random_state=None)

# %%
preds=clf_gini.predict(X_test)
pred=clf_infoG.predict(X_test)
predict=clf.predict(X_test)
pr=bdt.predict(X_test)

# %%
df=pd.DataFrame(test1.customerID)

# %%
df.loc[:,'Churn'] = pd.Series(pr)
df
# Out:
#       customerID  Churn
# 0     8180-AKMJV      1
# 1     4298-OYIFC      1
# 2     5566-SOEZD      0
# 3     9842-EFSYY      0
# 4     2272-WUSPA      0
# 5     4584-LBNMK      0
# 6     3898-GUYTS      0
# 7     0930-EHUZA      0
# 8     6413-XKKPU      0
# 9     9975-SKRNR      0
# 10    3703-KBKZP      1
# 11    1449-XQEMT      0
# 12    2626-URJFX      1
# 13    4973-MGTON      0
# 14    3682-YEUWS      0
# 15    1223-UNPKS      0
# 16    2612-RRIDN      1
# 17    4735-ASGMA      1
# 18    3446-QDSZF      0
# 19    3669-LVWZB      0
# 20    6892-EZDTG      1
# 21    5117-IFGPS      1
# 22    7379-FNIUJ      1
# 23    1627-AFWVJ      0
# 24    9725-SCPZG      1
# 25    5884-GCYMI      1
# 26    3217-FZDMN      1
# 27    4486-EFAEB      0
# 28    0060-FUALY      0
# 29    7853-GVUDZ      0
# ...          ...    ...
# 2083  1685-BQULA      0
# 2084  9053-EJUNL      0
# 2085  0666-UXTJO      0
# 2086  1471-GIQKQ      1
# 2087  4807-IZYOZ      0
# 2088  1122-JWTJW      1
# ...

# %%
df.to_csv('C:\\Users\\shreyas.raghavan\\Documents\\Personalization\\sub4.csv')
